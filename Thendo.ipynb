# %% [markdown]
# #My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Thendo Nemutavhanani**
#
# Data Engineer

# %% [markdown]
# *I am interested in data science because I want to able to build machine and deep learning algorithms to help grow my company*

# %% [markdown]
# It's suppose to add two numbers 2 and 3 and output the results

# %%
2+3
# Out:
# 5

# %% [markdown]
#
#   ***
#
# 1. Lions
# 2. Elephants
# 3. Birds
#
# ![gate_hura_01_m.jpg](attachment:87bca74d-4e37-4fc7-bcb8-1990d4e3ca5d.jpg)
